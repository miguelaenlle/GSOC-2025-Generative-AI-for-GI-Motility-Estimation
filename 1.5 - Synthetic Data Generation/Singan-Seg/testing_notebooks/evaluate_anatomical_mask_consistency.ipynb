# %%
import os
import cv2
from totalsegmentator.python_api import totalsegmentator

# %%
dataset_folder = '/home/miguel/GI/1.5 - Synthetic Data Generation/Singan-Seg/total_segmentator_eval_dataset/augmented_dataset_expansion_factor_0'

# %%
for cv_subject in os.listdir(dataset_folder):
    train_folder = os.path.join(dataset_folder, cv_subject, 'train')
    val_folder = os.path.join(dataset_folder, cv_subject, 'val')
