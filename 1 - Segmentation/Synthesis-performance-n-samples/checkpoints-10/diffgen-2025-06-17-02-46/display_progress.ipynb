# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
progress = pd.read_csv('progress.csv')

# %%
plt.plot(
    progress['step'],
    progress['loss'].rolling(100).mean(),
)

# %%
progress
# Out:
#        grad_norm      loss   loss_q0       mse    mse_q0  param_norm  samples  \
# 0       2.040971  1.015226  1.015226  1.001949  1.001949  346.936906        1
# 1       3.460517  0.843045  0.879282  0.834278  0.871709  346.938659       11
# 2       2.957322  0.631751  0.812113  0.618930  0.780436  346.949561       21
# 3       2.506999  0.393895  0.413264  0.389330  0.407939  346.963799       31
# 4       2.374737  0.297125  0.385689  0.291196  0.376211  346.999972       41
# ...          ...       ...       ...       ...       ...         ...      ...
# 14063   0.034367  0.000439  0.001623  0.000435  0.001609  508.343398   140631
# 14064   0.036460  0.001520  0.004054  0.001498  0.003991  508.344806   140641
# 14065   0.044021  0.004499  0.008573  0.004410  0.008398  508.348349   140651
# 14066   0.035566  0.001236  0.004433  0.001222  0.004373  508.350874   140661
# 14067   0.220904  0.038852  0.191590  0.030906  0.151883  508.355353   140671
#
# ...
