# %%
import os
import glob
import pandas as pd

# %%
stomach_data_and_masks_path = '/home/miguel/GI/0 - Data Exploration & Analysis/UW-Madison/stomach_data_and_masks_preparation/stomach_data_and_masks'

# %%
[filename[:-4] for filename in os.listdir(stomach_data_and_masks_path) if 'stomach_mask' not in filename]
# Out:
# ['case80_day10_slice_0097.png',
#  'case30_day1_slice_0060.png',
#  'case148_day20_slice_0073.png',
#  'case113_day12_slice_0071.png',
#  'case33_day21_slice_0104.png',
#  'case141_day13_slice_0056.png',
#  'case102_day0_slice_0097.png',
#  'case114_day17_slice_0076.png',
#  'case138_day12_slice_0068.png',
#  'case107_day0_slice_0086.png',
#  'case107_day0_slice_0077.png',
#  'case113_day19_slice_0071.png',
#  'case49_day0_slice_0057.png',
#  'case49_day13_slice_0061.png',
#  'case143_day18_slice_0053.png',
#  'case134_day0_slice_0045.png',
#  'case114_day0_slice_0080.png',
#  'case102_day0_slice_0093.png',
#  'case118_day14_slice_0065.png',
#  'case101_day32_slice_0082.png',
#  'case20_day24_slice_0069.png',
#  'case30_day1_slice_0072.png',
#  'case139_day14_slice_0110.png',
#  'case139_day14_slice_0103.png',
#  'case90_day29_slice_0072.png',
#  'case84_day21_slice_0079.png',
#  'case121_day16_slice_0079.png',
#  'case156_day0_slice_0083.png',
#  'case114_day0_slice_0081.png',
#  'case92_day0_slice_0063.png',
#  'case146_day24_slice_0065.png',
#  'case101_day20_slice_0084.png',
#  'case133_day25_slice_0071.png',
#  'case131_day0_slice_0052.png',
#  'case131_day19_slice_0081.png',
#  'case36_day16_slice_0054.png',
#  'case116_day0_slice_0056.png',
#  'case7_day13_slice_0081.png',
#  'case2_day2_slice_0077.png',
#  'case143_day18_slice_0039.png',
#  'case154_day16_slice_0068.png',
#  'case142_day16_slice_0069.png',
#  'case117_day16_slice_0038.png',
#  'case81_day28_slice_0061.png',
#  'case18_day0_slice_0068.png',
#  'case117_day17_slice_0018.png',
#  'case111_day19_slice_0067.png',
#  'case149_day15_slice_0073.png',
#  'case101_day20_slice_0070.png',
#  'case78_day18_slice_0107.png',
#  'case42_day19_slice_0094.png',
#  'case131_day0_slice_0078.png',
#  'case19_day0_slice_0060.png',
#  'case88_day36_slice_0097.png',
#  'case107_day19_slice_0045.png',
#  'case20_day22_slice_0081.png',
#  'case19_day14_slice_0054.png',
#  'case18_day17_slice_0068.png',
#  'case74_day0_slice_0100.png',
#  'case30_day0_slice_0121.png',
#  'case34_day0_slice_0035.png',
#  'case42_day19_slice_0096.png',
#  'case107_day0_slice_0072.png',
#  'case129_day24_slice_0062.png',
#  'case129_day0_slice_0071.png',
#  'case35_day0_slice_0065.png',
#  'case44_day20_slice_0058.png',
#  'case156_day11_slice_0099.png',
#  'case118_day16_slice_0052.png',
#  'case65_day0_slice_0077.png',
#  'case43_day20_slice_0079.png',
#  'case90_day29_slice_0098.png',
#  'case119_day25_slice_0089.png',
#  'case154_day14_slice_0045.png',
#  'case63_day26_slice_0068.png',
#  'case122_day27_slice_0071.png',
#  'case15_day0_slice_0072.png',
#  'case131_day21_slice_0058.png',
#  'case88_day38_slice_0096.png',
#  'case88_day0_slice_0088.png',
#  'case154_day17_slice_0071.png',
#  'case136_day27_slice_0084.png',
#  'case125_day16_slice_0075.png',
#  'case40_day17_slice_0063.png',
#  'case122_day24_slice_0060.png',
#  'case115_day0_slice_0083.png',
#  'case130_day20_slice_0042.png',
#  'case43_day20_slice_0055.png',
#  'case131_day23_slice_0050.png',
#  'case36_day6_slice_0059.png',
#  'case34_day0_slice_0032.png',
#  'case135_day17_slice_0058.png',
#  'case123_day22_slice_0077.png',
#  'case130_day20_slice_0047.png',
#  'case124_day0_slice_0072.png',
#  'case36_day16_slice_0042.png',
#  'case133_day23_slice_0049.png',
#  'case43_day20_slice_0061.png',
#  'case85_day0_slice_0084.png',
#  'case41_day0_slice_0062.png',
#  'case89_day19_slice_0063.png',
#  'case18_day19_slice_0064.png',
#  'case2_day2_slice_0088.png',
#  'case20_day24_slice_0072.png',
#  'case117_day16_slice_0030.png',
#  'case54_day30_slice_0047.png',
#  'case143_day23_slice_0057.png',
#  'case55_day0_slice_0078.png',
#  'case140_day0_slice_0081.png',
#  'case89_day20_slice_0067.png',
#  'case74_day15_slice_0088.png',
#  'case107_day21_slice_0063.png',
#  'case80_day10_slice_0094.png',
#  'case108_day10_slice_0086.png',
#  'case147_day14_slice_0068.png',
#  'case135_day0_slice_0054.png',
#  'case67_day0_slice_0049.png',
#  'case92_day0_slice_0088.png',
#  'case42_day17_slice_0074.png',
#  'case129_day27_slice_0062.png',
#  'case122_day18_slice_0054.png',
#  'case134_day22_slice_0064.png',
#  'case2_day3_slice_0047.png',
#  'case154_day0_slice_0058.png',
#  'case32_day20_slice_0085.png',
#  'case102_day0_slice_0102.png',
#  'case65_day28_slice_0115.png',
#  'case78_day30_slice_0100.png',
#  'case135_day0_slice_0079.png',
#  'case115_day0_slice_0067.png',
#  'case129_day22_slice_0077.png',
#  'case9_day20_slice_0046.png',
#  'case15_day20_slice_0060.png',
#  'case123_day22_slice_0085.png',
#  'case9_day0_slice_0038.png',
#  'case129_day0_slice_0054.png',
#  'case90_day29_slice_0079.png',
#  'case129_day20_slice_0050.png',
#  'case41_day0_slice_0050.png',
#  'case134_day22_slice_0042.png',
#  'case129_day22_slice_0067.png',
#  'case142_day16_slice_0059.png',
#  'case67_day12_slice_0060.png',
#  'case111_day19_slice_0068.png',
#  'case36_day16_slice_0051.png',
#  'case130_day0_slice_0049.png',
#  'case111_day19_slice_0066.png',
#  'case85_day0_slice_0087.png',
#  'case65_day0_slice_0083.png',
#  'case54_day39_slice_0084.png',
#  'case124_day19_slice_0064.png',
#  'case142_day0_slice_0047.png',
#  'case138_day12_slice_0066.png',
#  'case134_day22_slice_0060.png',
#  'case77_day18_slice_0094.png',
#  'case19_day22_slice_0057.png',
#  'case36_day0_slice_0088.png',
#  'case146_day0_slice_0063.png',
#  'case143_day0_slice_0080.png',
#  'case34_day15_slice_0058.png',
#  'case110_day16_slice_0067.png',
#  'case135_day0_slice_0076.png',
#  'case32_day18_slice_0090.png',
#  'case118_day14_slice_0071.png',
#  'case74_day0_slice_0082.png',
#  'case129_day24_slice_0078.png',
#  'case29_day14_slice_0084.png',
#  'case135_day0_slice_0048.png',
#  'case134_day21_slice_0049.png',
#  'case89_day20_slice_0050.png',
#  'case91_day0_slice_0058.png',
#  'case141_day13_slice_0044.png',
#  'case2_day1_slice_0057.png',
#  'case81_day28_slice_0056.png',
#  'case2_day4_slice_0066.png',
#  'case40_day0_slice_0078.png',
#  'case35_day13_slice_0037.png',
#  'case122_day27_slice_0046.png',
#  'case144_day0_slice_0063.png',
#  'case18_day25_slice_0055.png',
#  'case117_day0_slice_0062.png',
#  'case117_day17_slice_0016.png',
#  'case42_day19_slice_0089.png',
#  'case123_day0_slice_0071.png',
#  'case6_day20_slice_0068.png',
#  'case42_day19_slice_0075.png',
#  'case11_day0_slice_0071.png',
#  'case24_day25_slice_0066.png',
#  'case78_day0_slice_0094.png',
#  'case121_day0_slice_0084.png',
#  'case81_day0_slice_0077.png',
#  'case116_day0_slice_0062.png',
#  'case129_day27_slice_0065.png',
#  'case117_day13_slice_0011.png',
#  'case43_day26_slice_0082.png',
#  'case18_day25_slice_0067.png',
#  'case49_day0_slice_0064.png',
#  'case101_day26_slice_0083.png',
#  'case9_day22_slice_0071.png',
#  'case146_day25_slice_0033.png',
#  'case11_day13_slice_0059.png',
#  'case77_day20_slice_0094.png',
#  'case101_day32_slice_0075.png',
#  'case18_day0_slice_0079.png',
#  'case154_day0_slice_0065.png',
#  'case9_day0_slice_0057.png',
#  'case44_day0_slice_0051.png',
#  'case113_day22_slice_0048.png',
#  'case30_day1_slice_0063.png',
#  'case133_day25_slice_0046.png',
#  'case36_day0_slice_0099.png',
#  'case124_day0_slice_0060.png',
#  'case54_day35_slice_0062.png',
#  'case140_day0_slice_0079.png',
#  'case90_day22_slice_0090.png',
#  'case44_day0_slice_0069.png',
#  'case114_day17_slice_0048.png',
#  'case65_day0_slice_0082.png',
#  'case92_day0_slice_0073.png',
#  'case145_day19_slice_0060.png',
#  'case18_day0_slice_0066.png',
#  'case81_day30_slice_0089.png',
#  'case119_day0_slice_0059.png',
#  'case44_day0_slice_0070.png',
#  'case130_day22_slice_0061.png',
#  'case138_day0_slice_0059.png',
#  'case147_day19_slice_0081.png',
#  'case80_day14_slice_0081.png',
#  'case85_day29_slice_0083.png',
#  'case42_day0_slice_0081.png',
#  'case67_day16_slice_0053.png',
#  'case130_day22_slice_0064.png',
#  'case53_day0_slice_0074.png',
#  'case136_day27_slice_0079.png',
#  'case92_day0_slice_0070.png',
#  'case81_day28_slice_0076.png',
#  'case129_day22_slice_0078.png',
#  'case67_day16_slice_0041.png',
#  'case66_day0_slice_0063.png',
#  'case54_day0_slice_0043.png',
#  'case146_day25_slice_0042.png',
#  'case63_day26_slice_0064.png',
#  'case11_day13_slice_0039.png',
#  'case133_day23_slice_0062.png',
#  'case149_day12_slice_0072.png',
#  'case147_day18_slice_0068.png',
#  'case42_day19_slice_0106.png',
#  'case15_day0_slice_0065.png',
#  'case36_day6_slice_0051.png',
#  'case90_day0_slice_0063.png',
#  'case115_day0_slice_0081.png',
#  'case138_day11_slice_0077.png',
#  'case90_day22_slice_0096.png',
#  'case139_day18_slice_0071.png',
#  'case113_day0_slice_0058.png',
#  'case121_day16_slice_0071.png',
#  'case74_day18_slice_0098.png',
#  'case41_day0_slice_0046.png',
#  'case89_day19_slice_0086.png',
#  'case117_day0_slice_0075.png',
#  'case129_day27_slice_0087.png',
#  'case122_day27_slice_0058.png',
#  'case81_day30_slice_0098.png',
#  'case131_day23_slice_0066.png',
#  'case101_day22_slice_0064.png',
#  'case2_day5_slice_0079.png',
#  'case18_day25_slice_0070.png',
#  'case88_day36_slice_0091.png',
#  'case42_day19_slice_0085.png',
#  'case63_day18_slice_0070.png',
#  'case54_day0_slice_0061.png',
#  'case66_day0_slice_0073.png',
#  'case33_day0_slice_0073.png',
#  'case15_day0_slice_0064.png',
#  'case131_day19_slice_0052.png',
#  'case74_day0_slice_0092.png',
#  'case145_day20_slice_0083.png',
#  'case44_day19_slice_0079.png',
#  'case80_day14_slice_0069.png',
#  'case30_day0_slice_0107.png',
#  'case101_day32_slice_0062.png',
#  'case134_day0_slice_0067.png',
#  'case154_day0_slice_0051.png',
#  'case30_day0_slice_0098.png',
#  'case7_day13_slice_0059.png',
#  'case133_day0_slice_0062.png',
#  'case9_day0_slice_0050.png',
#  'case90_day29_slice_0059.png',
#  'case156_day11_slice_0081.png',
#  'case125_day16_slice_0079.png',
#  'case42_day0_slice_0106.png',
#  'case67_day0_slice_0055.png',
#  'case67_day16_slice_0045.png',
#  'case138_day11_slice_0050.png',
#  'case142_day16_slice_0070.png',
#  'case32_day19_slice_0075.png',
#  'case7_day19_slice_0083.png',
#  'case113_day16_slice_0062.png',
#  'case134_day0_slice_0051.png',
#  'case149_day15_slice_0068.png',
#  'case130_day20_slice_0070.png',
#  'case141_day27_slice_0064.png',
#  'case44_day20_slice_0081.png',
#  'case30_day1_slice_0075.png',
#  'case146_day0_slice_0062.png',
#  'case41_day25_slice_0085.png',
#  'case41_day25_slice_0070.png',
#  'case44_day19_slice_0087.png',
#  'case44_day0_slice_0060.png',
#  'case32_day18_slice_0094.png',
#  'case122_day27_slice_0056.png',
#  'case125_day16_slice_0060.png',
#  'case33_day21_slice_0106.png',
#  'case42_day19_slice_0108.png',
#  'case110_day16_slice_0066.png',
#  'case53_day0_slice_0072.png',
#  'case49_day0_slice_0048.png',
#  'case35_day15_slice_0057.png',
#  'case40_day0_slice_0085.png',
#  'case47_day27_slice_0039.png',
#  'case148_day0_slice_0085.png',
#  'case117_day13_slice_0004.png',
#  'case156_day11_slice_0098.png',
#  'case19_day14_slice_0050.png',
#  'case40_day17_slice_0066.png',
#  'case111_day19_slice_0069.png',
#  'case74_day18_slice_0104.png',
#  'case24_day25_slice_0070.png',
#  'case111_day0_slice_0057.png',
#  'case130_day20_slice_0049.png',
#  'case107_day0_slice_0094.png',
#  'case80_day0_slice_0076.png',
#  'case42_day0_slice_0085.png',
#  'case33_day0_slice_0095.png',
#  'case30_day1_slice_0066.png',
#  'case6_day0_slice_0071.png',
#  'case110_day12_slice_0056.png',
#  'case131_day23_slice_0069.png',
#  'case129_day27_slice_0060.png',
#  'case85_day0_slice_0076.png',
#  'case118_day0_slice_0036.png',
#  'case121_day16_slice_0052.png',
#  'case119_day0_slice_0073.png',
#  'case122_day27_slice_0057.png',
#  'case89_day17_slice_0053.png',
#  'case143_day18_slice_0030.png',
#  'case44_day0_slice_0044.png',
#  'case125_day15_slice_0067.png',
#  'case154_day13_slice_0044.png',
#  'case89_day17_slice_0078.png',
#  'case134_day21_slice_0045.png',
#  'case36_day8_slice_0051.png',
#  'case114_day17_slice_0071.png',
#  'case77_day18_slice_0086.png',
#  'case156_day10_slice_0114.png',
#  'case78_day26_slice_0096.png',
#  'case58_day0_slice_0049.png',
#  'case115_day0_slice_0084.png',
#  'case90_day29_slice_0093.png',
#  'case44_day0_slice_0063.png',
#  'case85_day29_slice_0095.png',
#  'case32_day20_slice_0079.png',
#  'case110_day16_slice_0065.png',
#  'case42_day17_slice_0101.png',
#  'case133_day0_slice_0055.png',
#  'case141_day27_slice_0037.png',
#  'case19_day12_slice_0034.png',
#  'case15_day0_slice_0074.png',
#  'case133_day0_slice_0053.png',
#  'case7_day0_slice_0098.png',
#  'case129_day27_slice_0058.png',
#  'case43_day20_slice_0064.png',
#  'case139_day0_slice_0066.png',
#  'case114_day15_slice_0069.png',
#  'case42_day0_slice_0105.png',
#  'case122_day18_slice_0064.png',
#  'case129_day20_slice_0047.png',
#  'case34_day0_slice_0044.png',
#  'case116_day0_slice_0073.png',
#  'case131_day23_slice_0058.png',
#  'case53_day0_slice_0086.png',
#  'case147_day18_slice_0075.png',
#  'case53_day0_slice_0069.png',
#  'case54_day35_slice_0064.png',
#  'case149_day0_slice_0067.png',
#  'case42_day19_slice_0080.png',
#  'case130_day22_slice_0053.png',
#  'case54_day39_slice_0072.png',
#  'case35_day13_slice_0061.png',
#  'case139_day18_slice_0073.png',
#  'case129_day27_slice_0081.png',
#  'case11_day13_slice_0045.png',
#  'case32_day17_slice_0105.png',
#  'case110_day12_slice_0062.png',
#  'case156_day0_slice_0078.png',
#  'case42_day0_slice_0083.png',
#  'case35_day15_slice_0045.png',
#  'case43_day20_slice_0068.png',
#  'case139_day14_slice_0117.png',
#  'case78_day0_slice_0098.png',
#  'case138_day12_slice_0080.png',
#  'case139_day14_slice_0104.png',
#  'case74_day13_slice_0108.png',
#  'case90_day0_slice_0072.png',
#  'case114_day0_slice_0047.png',
#  'case136_day27_slice_0064.png',
#  'case156_day0_slice_0059.png',
#  'case134_day22_slice_0050.png',
#  'case107_day21_slice_0057.png',
#  'case43_day26_slice_0058.png',
#  'case41_day0_slice_0058.png',
#  'case134_day0_slice_0056.png',
#  'case129_day24_slice_0065.png',
#  'case42_day17_slice_0092.png',
#  'case15_day0_slice_0062.png',
#  'case80_day10_slice_0092.png',
#  'case34_day0_slice_0051.png',
#  'case34_day16_slice_0048.png',
#  'case119_day25_slice_0086.png',
#  'case29_day13_slice_0088.png',
#  'case32_day17_slice_0104.png',
#  'case131_day19_slice_0059.png',
#  'case133_day0_slice_0063.png',
#  'case102_day0_slice_0113.png',
#  'case118_day14_slice_0078.png',
#  'case89_day19_slice_0084.png',
#  'case78_day0_slice_0100.png',
#  'case122_day24_slice_0063.png',
#  'case134_day22_slice_0063.png',
#  'case121_day16_slice_0070.png',
#  'case32_day0_slice_0062.png',
#  'case19_day18_slice_0037.png',
#  'case36_day0_slice_0091.png',
#  'case77_day18_slice_0098.png',
#  'case118_day0_slice_0027.png',
#  'case43_day26_slice_0060.png',
#  'case140_day0_slice_0074.png',
#  'case19_day0_slice_0057.png',
#  'case66_day0_slice_0067.png',
#  'case43_day26_slice_0078.png',
#  'case9_day22_slice_0065.png',
#  'case42_day19_slice_0095.png',
#  'case18_day19_slice_0073.png',
#  'case141_day27_slice_0031.png',
#  'case119_day20_slice_0071.png',
#  'case9_day0_slice_0037.png',
#  'case15_day20_slice_0067.png',
#  'case80_day10_slice_0085.png',
#  'case35_day12_slice_0044.png',
#  'case144_day15_slice_0070.png',
#  'case11_day12_slice_0056.png',
#  'case149_day12_slice_0079.png',
#  'case111_day19_slice_0060.png',
#  'case119_day21_slice_0059.png',
#  'case118_day0_slice_0039.png',
#  'case119_day21_slice_0055.png',
#  'case54_day35_slice_0075.png',
#  'case2_day1_slice_0070.png',
#  'case119_day25_slice_0075.png',
#  'case74_day0_slice_0086.png',
#  'case125_day0_slice_0051.png',
#  'case41_day0_slice_0067.png',
#  'case118_day16_slice_0058.png',
#  'case55_day0_slice_0066.png',
#  'case119_day19_slice_0059.png',
#  'case74_day19_slice_0082.png',
#  'case108_day10_slice_0085.png',
#  'case129_day24_slice_0076.png',
#  'case88_day0_slice_0091.png',
#  'case7_day19_slice_0089.png',
#  'case89_day21_slice_0017.png',
#  'case2_day2_slice_0080.png',
#  'case84_day0_slice_0083.png',
#  'case121_day16_slice_0091.png',
#  'case24_day0_slice_0059.png',
#  'case47_day0_slice_0051.png',
#  'case146_day25_slice_0027.png',
#  'case63_day0_slice_0072.png',
#  'case123_day0_slice_0069.png',
#  'case121_day16_slice_0068.png',
#  'case122_day25_slice_0045.png',
#  'case29_day0_slice_0065.png',
#  'case78_day0_slice_0108.png',
#  'case29_day13_slice_0076.png',
#  'case74_day15_slice_0103.png',
#  'case90_day29_slice_0091.png',
#  'case131_day19_slice_0064.png',
#  'case42_day17_slice_0090.png',
#  'case29_day14_slice_0086.png',
#  'case54_day30_slice_0049.png',
#  'case139_day14_slice_0086.png',
#  'case102_day0_slice_0089.png',
#  'case42_day19_slice_0090.png',
#  'case7_day13_slice_0079.png',
#  'case133_day23_slice_0065.png',
#  'case154_day0_slice_0076.png',
#  'case133_day23_slice_0069.png',
#  'case154_day16_slice_0045.png',
#  'case88_day36_slice_0083.png',
#  'case77_day20_slice_0085.png',
#  'case15_day20_slice_0063.png',
#  'case41_day32_slice_0104.png',
#  'case42_day0_slice_0094.png',
#  'case121_day14_slice_0077.png',
#  'case122_day0_slice_0052.png',
#  'case124_day0_slice_0095.png',
#  'case43_day0_slice_0068.png',
#  'case144_day0_slice_0057.png',
#  'case154_day17_slice_0058.png',
#  'case125_day16_slice_0083.png',
#  'case47_day29_slice_0058.png',
#  'case114_day0_slice_0079.png',
#  'case143_day23_slice_0072.png',
#  'case85_day29_slice_0077.png',
#  'case121_day16_slice_0056.png',
#  'case101_day32_slice_0077.png',
#  'case119_day20_slice_0070.png',
#  'case49_day15_slice_0065.png',
#  'case2_day4_slice_0082.png',
#  'case129_day0_slice_0086.png',
#  'case156_day11_slice_0100.png',
#  'case133_day0_slice_0068.png',
#  'case42_day19_slice_0084.png',
#  'case131_day15_slice_0029.png',
#  'case74_day13_slice_0107.png',
#  'case117_day17_slice_0019.png',
#  'case32_day17_slice_0080.png',
#  'case80_day10_slice_0077.png',
#  'case136_day25_slice_0091.png',
#  'case123_day0_slice_0050.png',
#  'case47_day27_slice_0048.png',
#  'case35_day15_slice_0037.png',
#  'case88_day36_slice_0085.png',
#  'case142_day0_slice_0045.png',
#  'case19_day18_slice_0041.png',
#  'case88_day0_slice_0104.png',
#  'case141_day0_slice_0053.png',
#  'case43_day26_slice_0062.png',
#  'case131_day23_slice_0054.png',
#  'case129_day22_slice_0075.png',
#  'case122_day0_slice_0053.png',
#  'case156_day11_slice_0110.png',
#  'case107_day0_slice_0084.png',
#  'case18_day17_slice_0076.png',
#  'case149_day15_slice_0065.png',
#  'case44_day19_slice_0062.png',
#  'case49_day13_slice_0074.png',
#  'case40_day17_slice_0075.png',
#  'case118_day16_slice_0051.png',
#  'case35_day0_slice_0071.png',
#  'case111_day0_slice_0061.png',
#  'case15_day20_slice_0072.png',
#  'case139_day0_slice_0060.png',
#  'case63_day20_slice_0087.png',
#  'case41_day32_slice_0097.png',
#  'case113_day19_slice_0053.png',
#  'case63_day20_slice_0067.png',
#  'case116_day0_slice_0069.png',
#  'case6_day0_slice_0060.png',
#  'case142_day16_slice_0058.png',
#  'case41_day25_slice_0051.png',
#  'case113_day0_slice_0062.png',
#  'case135_day0_slice_0080.png',
#  'case116_day0_slice_0052.png',
#  'case65_day28_slice_0109.png',
#  'case19_day18_slice_0058.png',
#  'case143_day0_slice_0070.png',
#  'case114_day17_slice_0074.png',
#  'case136_day27_slice_0057.png',
#  'case54_day32_slice_0056.png',
#  'case129_day0_slice_0090.png',
#  'case142_day0_slice_0062.png',
#  'case29_day14_slice_0090.png',
#  'case107_day21_slice_0051.png',
#  'case143_day0_slice_0063.png',
#  'case54_day32_slice_0050.png',
#  'case90_day22_slice_0084.png',
#  'case40_day17_slice_0085.png',
#  'case117_day13_slice_0035.png',
#  'case78_day0_slice_0080.png',
#  'case124_day19_slice_0068.png',
#  'case140_day10_slice_0048.png',
#  'case34_day16_slice_0031.png',
#  'case89_day20_slice_0069.png',
#  'case19_day14_slice_0047.png',
#  'case24_day24_slice_0058.png',
#  'case107_day21_slice_0069.png',
#  'case29_day14_slice_0098.png',
#  'case49_day0_slice_0062.png',
#  'case36_day14_slice_0044.png',
#  'case119_day21_slice_0057.png',
#  'case44_day19_slice_0086.png',
#  'case91_day0_slice_0073.png',
#  'case9_day0_slice_0053.png',
#  'case142_day14_slice_0063.png',
#  'case84_day23_slice_0085.png',
#  'case90_day0_slice_0095.png',
#  'case80_day14_slice_0100.png',
#  'case139_day0_slice_0089.png',
#  'case29_day14_slice_0100.png',
#  'case44_day20_slice_0073.png',
#  'case154_day13_slice_0067.png',
#  'case131_day19_slice_0061.png',
#  'case19_day22_slice_0045.png',
#  'case32_day0_slice_0082.png',
#  'case117_day17_slice_0015.png',
#  'case47_day0_slice_0044.png',
#  'case36_day6_slice_0061.png',
#  'case147_day14_slice_0063.png',
#  'case42_day17_slice_0085.png',
#  'case22_day0_slice_0097.png',
#  'case2_day3_slice_0049.png',
#  'case63_day22_slice_0073.png',
#  'case36_day8_slice_0061.png',
#  'case81_day30_slice_0100.png',
#  'case91_day0_slice_0050.png',
#  'case47_day27_slice_0033.png',
#  'case101_day32_slice_0091.png',
#  'case107_day0_slice_0097.png',
#  'case122_day25_slice_0076.png',
#  'case119_day25_slice_0065.png',
#  'case122_day0_slice_0078.png',
#  'case19_day12_slice_0033.png',
#  'case2_day2_slice_0054.png',
#  'case131_day19_slice_0065.png',
#  'case47_day29_slice_0052.png',
#  'case90_day0_slice_0088.png',
#  'case77_day0_slice_0094.png',
#  'case41_day25_slice_0053.png',
#  'case35_day12_slice_0040.png',
#  'case108_day10_slice_0074.png',
#  'case24_day24_slice_0074.png',
#  'case89_day19_slice_0065.png',
#  'case123_day22_slice_0095.png',
#  'case156_day10_slice_0112.png',
#  'case107_day0_slice_0089.png',
#  'case19_day0_slice_0042.png',
#  'case18_day0_slice_0065.png',
#  'case88_day36_slice_0101.png',
#  'case42_day19_slice_0093.png',
#  'case149_day0_slice_0073.png',
#  'case124_day20_slice_0066.png',
#  'case24_day25_slice_0056.png',
#  'case58_day0_slice_0070.png',
#  'case29_day13_slice_0064.png',
#  'case111_day19_slice_0083.png',
#  'case101_day26_slice_0088.png',
#  'case36_day14_slice_0049.png',
#  'case41_day25_slice_0058.png',
#  'case29_day14_slice_0085.png',
#  'case53_day0_slice_0080.png',
#  'case156_day11_slice_0087.png',
#  'case131_day15_slice_0025.png',
#  'case32_day19_slice_0086.png',
#  'case74_day15_slice_0096.png',
#  'case154_day13_slice_0054.png',
#  'case119_day0_slice_0070.png',
#  'case139_day0_slice_0059.png',
#  'case18_day0_slice_0062.png',
#  'case101_day32_slice_0094.png',
#  'case125_day15_slice_0070.png',
#  'case9_day0_slice_0040.png',
#  'case129_day20_slice_0077.png',
#  'case134_day22_slice_0062.png',
#  'case80_day14_slice_0065.png',
#  'case43_day26_slice_0068.png',
#  'case121_day14_slice_0062.png',
#  'case142_day14_slice_0064.png',
#  'case116_day0_slice_0053.png',
#  'case145_day20_slice_0092.png',
#  'case129_day20_slice_0073.png',
#  'case44_day20_slice_0083.png',
#  'case143_day18_slice_0049.png',
#  'case144_day14_slice_0074.png',
#  'case65_day25_slice_0081.png',
#  'case154_day14_slice_0060.png',
#  'case139_day16_slice_0092.png',
#  'case54_day32_slice_0067.png',
#  'case30_day1_slice_0068.png',
#  'case80_day10_slice_0098.png',
#  'case117_day15_slice_0019.png',
#  'case133_day25_slice_0050.png',
#  'case129_day22_slice_0073.png',
#  'case42_day0_slice_0079.png',
#  'case114_day17_slice_0054.png',
#  'case78_day18_slice_0083.png',
#  'case80_day14_slice_0086.png',
#  'case156_day10_slice_0113.png',
#  'case90_day29_slice_0077.png',
#  'case58_day0_slice_0060.png',
#  'case54_day32_slice_0068.png',
#  'case85_day23_slice_0096.png',
#  'case91_day0_slice_0069.png',
#  'case9_day0_slice_0065.png',
#  'case117_day0_slice_0078.png',
#  'case19_day22_slice_0064.png',
#  'case19_day12_slice_0063.png',
#  'case133_day23_slice_0047.png',
#  'case41_day0_slice_0059.png',
#  'case138_day0_slice_0074.png',
#  'case54_day0_slice_0041.png',
#  'case9_day22_slice_0061.png',
#  'case107_day21_slice_0065.png',
#  'case123_day20_slice_0083.png',
#  'case78_day26_slice_0101.png',
#  'case43_day0_slice_0070.png',
#  'case119_day25_slice_0081.png',
#  'case89_day21_slice_0023.png',
#  'case148_day20_slice_0084.png',
#  'case19_day22_slice_0060.png',
#  'case77_day20_slice_0089.png',
#  'case139_day14_slice_0115.png',
#  'case19_day18_slice_0057.png',
#  'case36_day0_slice_0080.png',
#  'case41_day0_slice_0055.png',
#  'case139_day14_slice_0082.png',
#  'case90_day22_slice_0071.png',
#  'case148_day20_slice_0072.png',
#  'case101_day26_slice_0096.png',
#  'case117_day0_slice_0070.png',
#  'case43_day22_slice_0078.png',
#  'case90_day22_slice_0104.png',
#  'case43_day18_slice_0052.png',
#  'case19_day22_slice_0061.png',
#  'case123_day0_slice_0080.png',
#  'case129_day20_slice_0072.png',
#  'case138_day0_slice_0090.png',
#  'case41_day0_slice_0052.png',
#  'case22_day0_slice_0081.png',
#  'case121_day14_slice_0089.png',
#  'case43_day20_slice_0054.png',
#  'case121_day16_slice_0077.png',
#  'case77_day18_slice_0085.png',
#  'case130_day0_slice_0036.png',
#  'case131_day21_slice_0059.png',
#  'case121_day16_slice_0069.png',
#  'case113_day22_slice_0057.png',
#  'case142_day0_slice_0058.png',
#  'case117_day15_slice_0013.png',
#  'case55_day0_slice_0063.png',
#  'case131_day19_slice_0066.png',
#  'case24_day24_slice_0063.png',
#  'case81_day28_slice_0063.png',
#  'case7_day19_slice_0070.png',
#  'case63_day22_slice_0064.png',
#  'case139_day18_slice_0063.png',
#  'case22_day0_slice_0073.png',
#  'case30_day0_slice_0120.png',
#  'case2_day2_slice_0086.png',
#  'case136_day0_slice_0072.png',
#  'case90_day0_slice_0070.png',
#  'case65_day25_slice_0078.png',
#  'case33_day0_slice_0067.png',
#  'case66_day36_slice_0087.png',
#  'case156_day0_slice_0084.png',
#  'case6_day0_slice_0084.png',
#  'case119_day25_slice_0077.png',
#  'case138_day12_slice_0100.png',
#  'case20_day22_slice_0067.png',
#  'case9_day22_slice_0049.png',
#  'case11_day12_slice_0060.png',
#  'case148_day0_slice_0070.png',
#  'case43_day22_slice_0058.png',
#  'case32_day0_slice_0063.png',
#  'case34_day16_slice_0046.png',
#  'case2_day4_slice_0049.png',
#  'case89_day21_slice_0024.png',
#  'case85_day27_slice_0092.png',
#  'case29_day14_slice_0079.png',
#  'case107_day0_slice_0081.png',
#  'case107_day19_slice_0071.png',
#  'case54_day0_slice_0048.png',
#  'case9_day22_slice_0048.png',
#  'case143_day0_slice_0057.png',
#  'case154_day0_slice_0050.png',
#  'case143_day23_slice_0043.png',
#  'case147_day14_slice_0081.png',
#  'case89_day19_slice_0053.png',
#  'case81_day30_slice_0083.png',
#  'case74_day13_slice_0102.png',
#  'case19_day14_slice_0067.png',
#  'case36_day8_slice_0056.png',
#  'case139_day16_slice_0076.png',
#  'case125_day0_slice_0080.png',
#  'case74_day18_slice_0109.png',
#  'case6_day20_slice_0070.png',
#  'case40_day16_slice_0071.png',
#  'case131_day21_slice_0061.png',
#  'case20_day24_slice_0081.png',
#  'case18_day21_slice_0071.png',
#  'case142_day0_slice_0059.png',
#  'case88_day0_slice_0087.png',
#  'case156_day0_slice_0065.png',
#  'case135_day17_slice_0050.png',
#  'case2_day4_slice_0073.png',
#  'case110_day16_slice_0077.png',
#  'case90_day22_slice_0075.png',
#  'case136_day27_slice_0091.png',
#  'case32_day18_slice_0085.png',
#  'case154_day14_slice_0057.png',
#  'case149_day0_slice_0075.png',
#  'case143_day23_slice_0068.png',
#  'case78_day30_slice_0099.png',
#  'case130_day22_slice_0062.png',
#  'case134_day21_slice_0055.png',
#  'case129_day22_slice_0068.png',
#  'case2_day3_slice_0064.png',
#  'case78_day18_slice_0102.png',
#  'case113_day16_slice_0076.png',
#  'case88_day0_slice_0099.png',
#  'case78_day0_slice_0093.png',
#  'case131_day23_slice_0049.png',
#  'case41_day0_slice_0063.png',
#  'case121_day16_slice_0097.png',
#  'case118_day0_slice_0034.png',
#  'case90_day29_slice_0064.png',
#  'case139_day0_slice_0082.png',
#  'case47_day0_slice_0053.png',
#  'case63_day0_slice_0097.png',
#  'case35_day18_slice_0069.png',
#  'case15_day20_slice_0062.png',
#  'case41_day32_slice_0113.png',
#  'case78_day30_slice_0082.png',
#  'case129_day22_slice_0072.png',
#  'case7_day19_slice_0093.png',
#  'case102_day0_slice_0095.png',
#  'case2_day5_slice_0054.png',
#  'case131_day21_slice_0048.png',
#  'case113_day19_slice_0075.png',
#  'case101_day22_slice_0066.png',
#  'case80_day10_slice_0080.png',
#  'case78_day22_slice_0086.png',
#  'case7_day19_slice_0069.png',
#  'case92_day0_slice_0067.png',
#  'case124_day19_slice_0065.png',
#  'case134_day22_slice_0040.png',
#  'case141_day27_slice_0057.png',
#  'case144_day0_slice_0065.png',
#  'case101_day22_slice_0086.png',
#  'case125_day16_slice_0076.png',
#  'case90_day0_slice_0100.png',
#  'case101_day26_slice_0075.png',
#  'case40_day17_slice_0068.png',
#  'case129_day27_slice_0068.png',
#  'case89_day17_slice_0075.png',
#  'case148_day20_slice_0074.png',
#  'case58_day0_slice_0059.png',
#  'case2_day2_slice_0083.png',
#  'case130_day20_slice_0065.png',
#  'case20_day24_slice_0080.png',
#  'case58_day0_slice_0057.png',
#  'case156_day10_slice_0120.png',
#  'case19_day22_slice_0047.png',
#  'case47_day0_slice_0042.png',
#  'case40_day0_slice_0062.png',
#  'case121_day16_slice_0065.png',
#  'case154_day14_slice_0058.png',
#  'case147_day14_slice_0069.png',
#  'case43_day20_slice_0072.png',
#  'case124_day19_slice_0085.png',
#  'case32_day20_slice_0069.png',
#  'case44_day20_slice_0087.png',
#  'case47_day0_slice_0043.png',
#  'case125_day15_slice_0085.png',
#  'case7_day13_slice_0078.png',
#  'case117_day16_slice_0035.png',
#  'case145_day19_slice_0057.png',
#  'case55_day18_slice_0105.png',
#  'case65_day28_slice_0106.png',
#  'case42_day0_slice_0073.png',
#  'case117_day16_slice_0033.png',
#  'case124_day20_slice_0065.png',
#  'case138_day12_slice_0076.png',
#  'case9_day20_slice_0034.png',
#  'case88_day36_slice_0089.png',
#  'case140_day0_slice_0084.png',
#  'case141_day13_slice_0070.png',
#  'case81_day28_slice_0070.png',
#  'case2_day2_slice_0062.png',
#  'case34_day15_slice_0056.png',
#  'case122_day27_slice_0047.png',
#  'case19_day0_slice_0055.png',
#  'case47_day27_slice_0045.png',
#  'case89_day20_slice_0055.png',
#  'case11_day0_slice_0042.png',
#  'case63_day0_slice_0078.png',
#  'case18_day25_slice_0072.png',
#  'case78_day0_slice_0078.png',
#  'case32_day0_slice_0059.png',
#  'case49_day0_slice_0058.png',
#  'case119_day20_slice_0061.png',
#  'case78_day30_slice_0105.png',
#  'case123_day20_slice_0076.png',
#  'case147_day19_slice_0066.png',
#  'case101_day22_slice_0069.png',
#  'case121_day16_slice_0058.png',
#  'case139_day18_slice_0034.png',
#  'case84_day0_slice_0084.png',
#  'case143_day23_slice_0050.png',
#  'case143_day18_slice_0066.png',
#  'case6_day0_slice_0065.png',
#  'case129_day22_slice_0051.png',
#  'case9_day20_slice_0050.png',
#  'case139_day18_slice_0066.png',
#  'case136_day27_slice_0089.png',
#  'case43_day18_slice_0060.png',
#  'case136_day0_slice_0077.png',
#  'case78_day22_slice_0093.png',
#  'case138_day0_slice_0087.png',
#  'case124_day20_slice_0090.png',
#  'case121_day14_slice_0085.png',
#  'case6_day20_slice_0073.png',
#  'case134_day22_slice_0046.png',
#  'case129_day22_slice_0059.png',
#  'case2_day2_slice_0060.png',
#  'case90_day22_slice_0101.png',
#  'case122_day18_slice_0056.png',
#  'case24_day25_slice_0076.png',
#  'case41_day32_slice_0093.png',
#  'case110_day16_slice_0061.png',
#  'case20_day22_slice_0070.png',
#  'case32_day0_slice_0060.png',
#  'case6_day0_slice_0080.png',
#  'case49_day0_slice_0050.png',
#  'case32_day0_slice_0086.png',
#  'case49_day13_slice_0086.png',
#  'case19_day18_slice_0051.png',
#  'case18_day0_slice_0087.png',
#  'case124_day19_slice_0071.png',
#  'case19_day0_slice_0046.png',
#  'case154_day13_slice_0064.png',
#  'case34_day15_slice_0065.png',
#  'case156_day0_slice_0070.png',
#  'case111_day0_slice_0050.png',
#  'case67_day12_slice_0051.png',
#  'case36_day14_slice_0046.png',
#  'case123_day22_slice_0083.png',
#  'case125_day16_slice_0087.png',
#  'case19_day18_slice_0062.png',
#  'case144_day0_slice_0060.png',
#  'case135_day17_slice_0045.png',
#  'case32_day0_slice_0074.png',
#  'case81_day30_slice_0066.png',
#  'case135_day17_slice_0051.png',
#  'case117_day16_slice_0037.png',
#  'case129_day27_slice_0084.png',
#  'case89_day17_slice_0071.png',
#  'case29_day13_slice_0081.png',
#  'case74_day18_slice_0101.png',
#  'case149_day12_slice_0075.png',
#  'case123_day0_slice_0051.png',
#  'case130_day20_slice_0061.png',
#  'case77_day0_slice_0090.png',
#  'case135_day0_slice_0059.png',
#  'case63_day18_slice_0090.png',
#  'case54_day32_slice_0054.png',
#  'case130_day20_slice_0076.png',
#  'case101_day22_slice_0081.png',
#  'case33_day0_slice_0075.png',
#  'case29_day0_slice_0078.png',
#  'case81_day30_slice_0087.png',
#  'case66_day36_slice_0090.png',
#  'case19_day14_slice_0039.png',
#  'case114_day15_slice_0045.png',
#  'case30_day1_slice_0065.png',
#  'case19_day22_slice_0042.png',
#  'case89_day20_slice_0064.png',
#  'case119_day0_slice_0076.png',
#  'case130_day0_slice_0062.png',
#  'case113_day22_slice_0045.png',
#  'case54_day39_slice_0063.png',
#  'case35_day15_slice_0035.png',
#  'case63_day26_slice_0089.png',
#  'case146_day24_slice_0059.png',
#  'case130_day22_slice_0073.png',
#  'case119_day21_slice_0073.png',
#  'case156_day11_slice_0092.png',
#  'case122_day27_slice_0050.png',
#  'case36_day6_slice_0052.png',
#  'case113_day16_slice_0074.png',
#  'case77_day18_slice_0110.png',
#  'case2_day2_slice_0067.png',
#  'case116_day0_slice_0058.png',
#  'case77_day0_slice_0068.png',
#  'case131_day21_slice_0074.png',
#  'case131_day21_slice_0071.png',
#  'case141_day27_slice_0044.png',
#  'case102_day0_slice_0085.png',
#  'case122_day27_slice_0051.png',
#  'case22_day0_slice_0099.png',
#  'case141_day13_slice_0072.png',
#  'case19_day0_slice_0039.png',
#  'case91_day0_slice_0067.png',
#  'case108_day0_slice_0053.png',
#  'case154_day13_slice_0051.png',
#  'case47_day0_slice_0055.png',
#  'case90_day29_slice_0051.png',
#  'case80_day10_slice_0108.png',
#  'case78_day26_slice_0095.png',
#  'case101_day22_slice_0067.png',
#  ...]

# %%
import os

# %%
os.listdir('checkpoints-100')
# Out:
# ['diffgen-2025-06-17-14-04']

# %%
2.67*5
# Out:
# 13.35

# %%
checkpoint_folder_name = f'checkpoints-100'
diffuse_gen_folder = max(
    (entry for entry in os.scandir(checkpoint_folder_name) if entry.is_dir()),
    key=lambda e: e.stat().st_mtime
).name

main_py = '/home/miguel/GI/1.5 - Synthetic Data Generation/diffuse-gen/diffuse-gen/main.py'

folder = f'{checkpoint_folder_name}/{diffuse_gen_folder}'

latest_model_file = max(
    (entry for entry in os.scandir(folder) if entry.is_file() and 'model' in entry.name and entry.name.endswith('.pt')),
    key=lambda e: e.stat().st_ctime  # Use st_mtime if you want "last modified" instead
).name

# %%
latest_model_file
# Out:
# 'model000011.pt'

# %%
import os
import pandas as pd

# %%
stomach_data_and_masks_dir_path = '/home/miguel/GI/0 - Data Exploration & Analysis/GI-Roberta/gi-roberta-dataset/full_dataset'

available_filenames = [filename for filename in os.listdir(stomach_data_and_masks_dir_path) if 'mask' not in filename]

# %%
filenames_and_subjects = pd.DataFrame({
    'image_filename': available_filenames,
    'subject': ["-".join(filename.split("-")[:2]) for filename in available_filenames]
})

# %%
filenames_and_subjects
# Out:
#                 image_filename subject
# 0    FD-032-slice-04-image.png  FD-032
# 1    FD-027-slice-71-image.png  FD-027
# 2    FD-027-slice-24-image.png  FD-027
# 3    FD-027-slice-47-image.png  FD-027
# 4    FD-031-slice-16-image.png  FD-031
# ..                         ...     ...
# 355  FD-030-slice-14-image.png  FD-030
# 356  FD-029-slice-58-image.png  FD-029
# 357  FD-030-slice-24-image.png  FD-030
# 358  FD-032-slice-16-image.png  FD-032
# 359  FD-032-slice-57-image.png  FD-032
#
# [360 rows x 2 columns]
