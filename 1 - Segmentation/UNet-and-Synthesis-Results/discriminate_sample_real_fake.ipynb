# %%
import os

# %%
for file in os.listdir('/home/miguel/GI/1 - Segmentation/UNet-and-Synthesis-Results/train_augmented_singan'):
    if 'stomach_mask' not in file:
        file = file[:-4]
        print(file)
# Out:
# 25_mask_mask_1
# case146_day24_slice_0060_image
# case18_day25_slice_0070_image
# case145_day19_slice_0075_image
# case108_day10_slice_0082_image
# 15_img_image_19
# case129_day24_slice_0084_image
# case54_day0_slice_0053_image
# case147_day19_slice_0070_image
# case42_day17_slice_0088_image
# case119_day20_slice_0059_image
# case85_day29_slice_0087_image
# case117_day0_slice_0062_image
# case41_day25_slice_0053_image
# 11_mask_mask_32
# case89_day0_slice_0085_image
# case55_day20_slice_0093_image
# case118_day0_slice_0037_image
# case139_day18_slice_0053_image
# case145_day20_slice_0084_image
# case122_day24_slice_0054_image
# case33_day0_slice_0075_image
# case43_day26_slice_0062_image
# case130_day20_slice_0077_image
# case121_day14_slice_0090_image
# case20_day24_slice_0076_image
# case119_day0_slice_0065_image
# case131_day19_slice_0052_image
# case122_day0_slice_0051_image
# 18_img_image_4
# 3_img_image_18
# case67_day12_slice_0063_image
# case36_day0_slice_0097_image
# ...
